# %% [markdown]
# # Validating the Kafka Data Stream

# %%
# !pip install kafka-python

# %%
# connect to kafka and print the data
KAFKA_BROKERS = ['kafka1:9092', 'kafka2:9092']
TOPICS = {
    'users': 'new_users',
    'transactions': 'new_transactions',
    'products': 'new_products',
    'sessions': 'new_sessions'
}
    

from kafka import KafkaConsumer
from IPython.display import clear_output
import json

consumer = KafkaConsumer(
    *TOPICS.values(),
    bootstrap_servers=KAFKA_BROKERS,
    auto_offset_reset='earliest',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

for i, message in enumerate(consumer):
    if i % 20 == 0:
        clear_output(wait=True)
    
    print(f"Topic: {message.topic}, Partition: {message.partition}, Offset: {message.offset}")
    print(f"Key: {message.key}, Value: {message.value}")
    print("-" * 50)
# Out:
# Topic: new_products, Partition: 0, Offset: 210
# Key: None, Value: {'product_id': '4ae07f84-cf41-4d1e-8029-83e8022e4fa1', 'name': 'Product_3089', 'category': 'Home', 'price': 35.43, 'inventory': 225, 'ratings': 3.0}
# --------------------------------------------------
# Topic: new_users, Partition: 0, Offset: 210
# Key: None, Value: {'user_id': 'f01b317f-f896-4e0f-bd1a-bc585b2fb909', 'email': 'user_320577@example.com', 'age': 21, 'country': 'USA', 'registeration_date': '2025-11-23T21:04:24.625956'}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 210
# Key: None, Value: {'transaction_id': 'd92f2357-9c25-4d61-ad5d-fce9f9d1e880', 'user_id': '3169fc5e-47f9-4ecf-8ff0-08c2b4870d4e', 'timestamp': '2025-11-23T21:04:24.626243', 'products': [{'product_id': '3c2290ae-15ac-477d-b4b0-e6c1de51aaf0', 'quantity': 1, 'price': 486.55}], 'total_amount': 486.55, 'payment_method': 'Apple Pay'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 210
# Key: None, Value: {'user_id': '0e8b0391-72cb-4278-89ef-1f1c28b077af', 'session_id': '9f428ffb-110c-4501-9ffc-340b3a63a56a', 'timestamp': '2025-11-23T21:04:24.626356', 'events': [{'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:24.626326'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:24.626326'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:24.626326'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:24.626326'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:24.626326'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:24.626326'}]}
# --------------------------------------------------
# Topic: new_products, Partition: 0, Offset: 211
# Key: None, Value: {'product_id': 'a2c61ae9-a1d1-4ef9-bf70-09a848161fb8', 'name': 'Product_7219', 'category': 'Books', 'price': 1073.68, 'inventory': 747, 'ratings': 3.2}
# --------------------------------------------------
# Topic: new_users, Partition: 0, Offset: 211
# Key: None, Value: {'user_id': '432add37-fc60-4add-b3ba-4350bf686310', 'email': 'user_590046@example.com', 'age': 88, 'country': 'UK', 'registeration_date': '2025-11-23T21:04:27.101100'}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 211
# Key: None, Value: {'transaction_id': '34b56a83-3cae-4164-9c14-af0b52e2f3a7', 'user_id': 'c9ffedd4-b6a1-41ef-a786-c34e6e62a4a9', 'timestamp': '2025-11-23T21:04:27.102056', 'products': [{'product_id': '31683805-3569-467b-bd55-f3467f3ae6a6', 'quantity': 1, 'price': 826.42}, {'product_id': '22b6da45-d193-4d33-a35a-961e3295c181', 'quantity': 1, 'price': 93.29}, {'product_id': '1f5545cd-a876-4d3e-8b99-e0ce40cd0f64', 'quantity': 3, 'price': 182.74}], 'total_amount': 1467.93, 'payment_method': 'PayPal'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 211
# Key: None, Value: {'user_id': '070e145d-802b-485a-85a9-cb2051ccc950', 'session_id': 'dc9dfebd-9236-4015-ae51-02c708e13c9d', 'timestamp': '2025-11-23T21:04:27.102433', 'events': [{'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:27.102267'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:27.102267'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:27.102267'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:27.102267'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:27.102267'}]}
# --------------------------------------------------
# Topic: new_products, Partition: 0, Offset: 212
# Key: None, Value: {'product_id': 'cd75c156-5165-4a7d-9dcc-5660daaaf24c', 'name': 'Product_7105', 'category': 'Clothing', 'price': 1158.28, 'inventory': 720, 'ratings': 2.5}
# --------------------------------------------------
# Topic: new_users, Partition: 0, Offset: 212
# Key: None, Value: {'user_id': 'a8660109-f9b4-4231-a0d6-4a83e4d173fd', 'email': 'user_634667@example.com', 'age': 60, 'country': 'USA', 'registeration_date': '2025-11-23T21:04:29.399790'}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 212
# Key: None, Value: {'transaction_id': '59164cf2-b0b7-4304-8a43-998156daff4c', 'user_id': '1d323135-c040-408c-8254-f95f7dbb950a', 'timestamp': '2025-11-23T21:04:29.400730', 'products': [{'product_id': '6efdd04a-ed1a-4c30-8c5c-6c160075da44', 'quantity': 2, 'price': 70.26}, {'product_id': 'de2149ca-17e3-4d93-906b-c389b89a6a19', 'quantity': 2, 'price': 853.52}, {'product_id': '7a551327-31a6-4098-824d-fc88e933ba33', 'quantity': 1, 'price': 119.13}], 'total_amount': 1966.69, 'payment_method': 'Apple Pay'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 212
# Key: None, Value: {'user_id': '770ad11a-2e19-4f2a-bebf-361ce93416fe', 'session_id': '2f3c44f5-7fef-4586-8abb-31057de8c6bc', 'timestamp': '2025-11-23T21:04:29.401162', 'events': [{'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:29.401086'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:29.401086'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:29.401086'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:29.401086'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:29.401086'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:29.401086'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:29.401086'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:29.401086'}]}
# --------------------------------------------------
# Topic: new_products, Partition: 0, Offset: 213
# Key: None, Value: {'product_id': '0d275c0d-16f1-499e-aca5-36ed89bfc7ed', 'name': 'Product_1702', 'category': 'Beauty', 'price': 191.84, 'inventory': 16, 'ratings': 1.1}
# --------------------------------------------------
# Topic: new_users, Partition: 0, Offset: 213
# Key: None, Value: {'user_id': '24cc50bf-d0ff-4334-87ad-6267eff4c6fa', 'email': 'user_117261@example.com', 'age': 26, 'country': 'USA', 'registeration_date': '2025-11-23T21:04:31.579851'}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 213
# Key: None, Value: {'transaction_id': '18e21cb4-69e9-4493-b7a5-a4ccfb4f9ad3', 'user_id': 'd120a957-3824-4c94-a5ff-adb69d197198', 'timestamp': '2025-11-23T21:04:31.580550', 'products': [{'product_id': '4f1dd743-bed2-4eba-8a58-6819e3242152', 'quantity': 3, 'price': 573.04}, {'product_id': '54840335-92e4-463e-a8ec-8f796f255a8e', 'quantity': 3, 'price': 688.83}, {'product_id': '4e5dbf93-7b91-41a7-9698-4f3c835f615c', 'quantity': 1, 'price': 911.51}, {'product_id': '6744cdc7-9e96-405c-9f35-d773417e8da5', 'quantity': 3, 'price': 724.81}, {'product_id': '40a36c26-d224-4739-bcbd-73d995ea67b5', 'quantity': 2, 'price': 67.0}], 'total_amount': 7005.55, 'payment_method': 'Debit Card'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 213
# Key: None, Value: {'user_id': 'ba02276b-14ec-4aed-a865-bde82b39fb6d', 'session_id': '0df44830-0aab-4542-a1a3-5d89cb3b78ac', 'timestamp': '2025-11-23T21:04:31.580695', 'events': [{'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:31.580672'}]}
# --------------------------------------------------
# Topic: new_users, Partition: 0, Offset: 214
# Key: None, Value: {'user_id': '719adba0-1e5c-4810-be13-c9f3b7f24a3e', 'email': 'user_985421@example.com', 'age': 34, 'country': 'Canada', 'registeration_date': '2025-11-23T21:04:34.254409'}
# --------------------------------------------------
# Topic: new_products, Partition: 0, Offset: 214
# Key: None, Value: {'product_id': '914cedf0-27c1-42b9-963e-ec8ed130c0fb', 'name': 'Product_7314', 'category': 'Beauty', 'price': 1210.51, 'inventory': 201, 'ratings': 2.2}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 214
# Key: None, Value: {'transaction_id': '157024d5-1ffa-4803-bd55-ede0e25877ec', 'user_id': 'ff1d0d11-4e29-4cd5-9d3c-4ed5d85516a9', 'timestamp': '2025-11-23T21:04:34.256534', 'products': [{'product_id': '690cbd9e-3bc6-4966-93c9-79670557a6f8', 'quantity': 2, 'price': 677.48}, {'product_id': '913e6912-70c6-403c-b6c0-c50e246b91e9', 'quantity': 3, 'price': 336.27}], 'total_amount': 2363.77, 'payment_method': 'Credit Card'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 214
# Key: None, Value: {'user_id': 'ff7dd5e7-65fc-4a72-b8e6-eb3aea556f02', 'session_id': '0b56bcff-4b41-4333-b0e6-e66a94d7efa4', 'timestamp': '2025-11-23T21:04:34.256989', 'events': [{'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-23T21:04:34.256875'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-23T21:04:34.256875'}]}
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 22
#      13 import json
#      15 consumer = KafkaConsumer(
#      16     *TOPICS.values(),
#      17     bootstrap_servers=KAFKA_BROKERS,
#      18     auto_offset_reset='earliest',
#      19     value_deserializer=lambda x: json.loads(x.decode('utf-8'))
#      20 )
# ---> 22 for i, message in enumerate(consumer):
#      23     if i % 20 == 0:
#      24         clear_output(wait=True)
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /opt/conda/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:
