# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.3.0-py2.py3-none-any.whl.metadata (10.0 kB)
# Downloading kafka_python-2.3.0-py2.py3-none-any.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.3/326.3 kB 1.6 MB/s eta 0:00:00a 0:00:01m
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.3.0

# %% [markdown]
# # GlobalMart Streaming Data Generator
# Streams have different distribution and patterns of data generation, to make seem more realistic.
#
# ### User Stream
# User stream has a constant rate of 10 users per second.
# - Users age is normally distributed centered at 26 and std 10.
# - Users country is selected from a list of countries with weights based on population.
# - Users email is generated using the user_id.
#
# ### Product Stream
# - Products are generated with a constant rate of 10 products per second.
# - Products price is dependent on the category.
# - Products inventory is dependent on the category.
# - Product ratings are distributed normally centered at 4.2 and std 0.8.
#
# ### Transaction Stream
# - Transactions are generated with a constant rate of 100 transactions per second.
# - Transactions are generated using existing users and products if available.
#
# ### Session Stream
# - Everything is random, except users; it uses existing users to generate sessions.

# %%
import time
import json
import random
import uuid
from datetime import datetime
from kafka import KafkaProducer

# Configuration
# Using the service names from docker-compose.yml as we expect this to run inside the docker network
KAFKA_BROKERS = ['kafka1:9092', 'kafka2:9092']

TOPICS = {
    'users': 'new_users',
    'transactions': 'new_transactions',
    'products': 'new_products',
    'sessions': 'new_sessions'
}

# Global pools to store generated entities for referential integrity simulation
USER_POOL = []
PRODUCT_POOL = []

def get_producer():
    """Create and return a KafkaProducer instance."""
    try:
        producer = KafkaProducer(
            bootstrap_servers=KAFKA_BROKERS,
            value_serializer=lambda v: json.dumps(v).encode('utf-8')
        )
        print(f"Connected to Kafka at {KAFKA_BROKERS}")
        return producer
    except Exception as e:
        print(f"Error connecting to Kafka: {e}")
        return None

# --- Data Generators ---

def generate_user():
    """Generate a random user record with realistic distributions."""
    # Weighted countries based on approximate population (simplified relative weights)
    countries = ["Egypt", "Eswatini", "Timor-Leste", "Cambodia", "Federated States of Micronesia"]
    weights = [110, 1.2, 1.3, 16, 0.1] # Rough relative population scale
    
    # Age: Normal distribution centered at 26, clipped to realistic bounds
    age = int(random.gauss(26, 10))
    age = max(18, min(90, age))
    
    domains = ["example.com", "gmail.com", "yahoo.com", "hotmail.com", "outlook.com"]
    
    user_id = str(uuid.uuid4())
    
    user = {
        "user_id": user_id,
        # Using user_id in email ensures uniqueness better than random int
        "email": f"user_{user_id}@{random.choice(domains)}",
        "age": age,
        "country": random.choices(countries, weights=weights, k=1)[0],
        "registeration_date": datetime.now().isoformat()
    }
    
    USER_POOL.append(user)
    # Keep pool size manageable
    if len(USER_POOL) > 10000:
        USER_POOL.pop(0)
        
    return user

def generate_product():
    """Generate a random product record with category-specific biases."""
    categories = ["Electronics", "Clothing", "Home", "Books", "Sports", "Beauty", "Toys"]
    category = random.choice(categories)
    
    # Category biases for price and inventory
    if category == "Electronics":
        price = round(random.uniform(100.0, 3000.0), 2)
        inventory = random.randint(10, 200)
    elif category == "Books":
        price = round(random.uniform(5.0, 50.0), 2)
        inventory = random.randint(50, 2000)
    elif category == "Clothing":
        price = round(random.uniform(10.0, 200.0), 2)
        inventory = random.randint(20, 500)
    else:
        price = round(random.uniform(10.0, 500.0), 2)
        inventory = random.randint(0, 1000)

    # Ratings: Biased normal distribution towards higher ratings (3.5 - 5.0)
    rating = random.gauss(4.2, 0.8)
    rating = round(max(1.0, min(5.0, rating)), 1)

    product = {
        "product_id": str(uuid.uuid4()),
        "name": f"{category}_Product_{random.randint(1, 10000)}",
        "category": category,
        "price": price,
        "inventory": inventory,
        "ratings": rating
    }
    
    PRODUCT_POOL.append(product)
    if len(PRODUCT_POOL) > 5000:
        PRODUCT_POOL.pop(0)
        
    return product

def generate_transaction():
    """Generate a random transaction record using existing users and products if available."""
    products = []
    total_amount = 0.0
    num_products = random.randint(1, 5)
    
    # Use existing user if available to establish country preference
    if USER_POOL:
        user_record = random.choice(USER_POOL)
        user_id = user_record["user_id"]
        user_country = user_record.get("country", "Unknown")
    else:
        user_id = str(uuid.uuid4())
        user_country = "Unknown"

    # Define simple category preferences by country
    country_preferences = {
        "Egypt": ["Electronics", "Clothing"],
        "Eswatini": ["Home", "Books"],
        "Timor-Leste": ["Sports", "Beauty"],
        "Cambodia": ["Toys", "Electronics"],
        "Federated States of Micronesia": ["Clothing", "Home"]
    }

    preferred_categories = country_preferences.get(user_country, [])
    
    for _ in range(num_products):
        if PRODUCT_POOL:
            # Filter pool by preference if applicable (50% chance to stick to preference)
            candidates = PRODUCT_POOL
            if preferred_categories and random.random() < 0.5:
                preferred_candidates = [p for p in PRODUCT_POOL if p["category"] in preferred_categories]
                if preferred_candidates:
                    candidates = preferred_candidates
            
            prod = random.choice(candidates)
            prod_id = prod["product_id"]
            price = prod["price"]
        else:
            prod_id = str(uuid.uuid4())
            price = round(random.uniform(10.0, 1000.0), 2)
            
        quantity = random.randint(1, 3)
        products.append({
            "product_id": prod_id,
            "quantity": quantity,
            "price": price
        })
        total_amount += price * quantity
    
    return {
        "transaction_id": str(uuid.uuid4()),
        "user_id": user_id,
        "timestamp": datetime.now().isoformat(),
        "products": products,
        "total_amount": round(total_amount, 2),
        "payment_method": random.choice(["Credit Card", "PayPal", "Debit Card", "Apple Pay", "Google Pay"])
    }

def generate_session():
    """Generate a random session record."""
    events = []
    base_time = datetime.now()
    num_events = random.randint(1, 10)
    
    user_id = random.choice(USER_POOL)["user_id"] if USER_POOL else str(uuid.uuid4())
    
    for i in range(num_events):
        events.append({
            "eventType": random.choice(["ADD_TO_CART", "REMOVE_FROM_CART", "CLEAR_CART"]),
            "timestamp": base_time.isoformat() 
        })
    
    return {
        "user_id": user_id,
        "session_id": str(uuid.uuid4()),
        "timestamp": datetime.now().isoformat(),
        "events": events
    }

# %%
def main():
    print("Initializing Kafka Producer...")
    producer = get_producer()
    
    if not producer:
        print("Failed to initialize producer. Please check your Kafka connection settings.")
        return

    print("Starting data stream. Press Ctrl+C to stop.")
    
    try:
        while True:
            # Produce User
            user_data = generate_user()
            producer.send(TOPICS['users'], user_data)
            
            # Produce Product
            product_data = generate_product()
            producer.send(TOPICS['products'], product_data)

            for _ in range(10): 
                # Produce Transaction
                transaction_data = generate_transaction()
                producer.send(TOPICS['transactions'], transaction_data)
            
                # Produce Session
                session_data = generate_session()
                producer.send(TOPICS['sessions'], session_data)
            
            # Flush periodically to ensure data is sent
            producer.flush()
            
            print(f"Produced 4 records (User, Product, Transaction, Session) at {datetime.now().strftime('%H:%M:%S')}")
            
            # Sleep for a random interval to simulate continuous streaming
            time.sleep(random.uniform(1.0, 3.0))

    except KeyboardInterrupt:
        print("\nStopping stream...")
    except Exception as e:
        print(f"\nAn error occurred: {e}")
    finally:
        if producer:
            producer.close()
            print("Producer closed.")

if __name__ == "__main__":
    main()
# Out:
# Initializing Kafka Producer...
# Connected to Kafka at ['kafka1:9092', 'kafka2:9092']
# Starting data stream. Press Ctrl+C to stop.
# Produced 4 records (User, Product, Transaction, Session) at 12:47:23
# Produced 4 records (User, Product, Transaction, Session) at 12:47:25
# Produced 4 records (User, Product, Transaction, Session) at 12:47:28
# Produced 4 records (User, Product, Transaction, Session) at 12:47:30
# Produced 4 records (User, Product, Transaction, Session) at 12:47:32
# Produced 4 records (User, Product, Transaction, Session) at 12:47:33
# Produced 4 records (User, Product, Transaction, Session) at 12:47:34
# Produced 4 records (User, Product, Transaction, Session) at 12:47:37
# Produced 4 records (User, Product, Transaction, Session) at 12:47:38
# Produced 4 records (User, Product, Transaction, Session) at 12:47:40
# Produced 4 records (User, Product, Transaction, Session) at 12:47:42
# Produced 4 records (User, Product, Transaction, Session) at 12:47:44
# Produced 4 records (User, Product, Transaction, Session) at 12:47:45
# Produced 4 records (User, Product, Transaction, Session) at 12:47:48
# Produced 4 records (User, Product, Transaction, Session) at 12:47:50
# Produced 4 records (User, Product, Transaction, Session) at 12:47:51
# Produced 4 records (User, Product, Transaction, Session) at 12:47:53
# Produced 4 records (User, Product, Transaction, Session) at 12:47:56
# Produced 4 records (User, Product, Transaction, Session) at 12:47:59
# Produced 4 records (User, Product, Transaction, Session) at 12:48:01
# Produced 4 records (User, Product, Transaction, Session) at 12:48:03
# Produced 4 records (User, Product, Transaction, Session) at 12:48:04
# Produced 4 records (User, Product, Transaction, Session) at 12:48:07
# Produced 4 records (User, Product, Transaction, Session) at 12:48:09
# Produced 4 records (User, Product, Transaction, Session) at 12:48:12
# Produced 4 records (User, Product, Transaction, Session) at 12:48:14
# Produced 4 records (User, Product, Transaction, Session) at 12:48:17
# Produced 4 records (User, Product, Transaction, Session) at 12:48:18
# Produced 4 records (User, Product, Transaction, Session) at 12:48:19
# Produced 4 records (User, Product, Transaction, Session) at 12:48:21
# Produced 4 records (User, Product, Transaction, Session) at 12:48:22
# Produced 4 records (User, Product, Transaction, Session) at 12:48:24
# Produced 4 records (User, Product, Transaction, Session) at 12:48:26
# Produced 4 records (User, Product, Transaction, Session) at 12:48:28
# Produced 4 records (User, Product, Transaction, Session) at 12:48:31
# Produced 4 records (User, Product, Transaction, Session) at 12:48:32
# Produced 4 records (User, Product, Transaction, Session) at 12:48:35
# Produced 4 records (User, Product, Transaction, Session) at 12:48:38
# Produced 4 records (User, Product, Transaction, Session) at 12:48:41
# Produced 4 records (User, Product, Transaction, Session) at 12:48:42
# Produced 4 records (User, Product, Transaction, Session) at 12:48:44
# Produced 4 records (User, Product, Transaction, Session) at 12:48:47
# Produced 4 records (User, Product, Transaction, Session) at 12:48:48
# Produced 4 records (User, Product, Transaction, Session) at 12:48:51
# Produced 4 records (User, Product, Transaction, Session) at 12:48:53
# Produced 4 records (User, Product, Transaction, Session) at 12:48:55
# Produced 4 records (User, Product, Transaction, Session) at 12:48:57
# Produced 4 records (User, Product, Transaction, Session) at 12:48:59
# Produced 4 records (User, Product, Transaction, Session) at 12:49:01
# Produced 4 records (User, Product, Transaction, Session) at 12:49:02
# Produced 4 records (User, Product, Transaction, Session) at 12:49:03
# Produced 4 records (User, Product, Transaction, Session) at 12:49:04
# Produced 4 records (User, Product, Transaction, Session) at 12:49:07
# Produced 4 records (User, Product, Transaction, Session) at 12:49:09
# Produced 4 records (User, Product, Transaction, Session) at 12:49:11
# Produced 4 records (User, Product, Transaction, Session) at 12:49:12
# Produced 4 records (User, Product, Transaction, Session) at 12:49:15
# Produced 4 records (User, Product, Transaction, Session) at 12:49:17
# Produced 4 records (User, Product, Transaction, Session) at 12:49:18
# Produced 4 records (User, Product, Transaction, Session) at 12:49:20
# Produced 4 records (User, Product, Transaction, Session) at 12:49:23
# Produced 4 records (User, Product, Transaction, Session) at 12:49:25
# Produced 4 records (User, Product, Transaction, Session) at 12:49:27
# Produced 4 records (User, Product, Transaction, Session) at 12:49:28
# Produced 4 records (User, Product, Transaction, Session) at 12:49:31
# Produced 4 records (User, Product, Transaction, Session) at 12:49:32
# Produced 4 records (User, Product, Transaction, Session) at 12:49:35
# Produced 4 records (User, Product, Transaction, Session) at 12:49:36
# Produced 4 records (User, Product, Transaction, Session) at 12:49:38
# Produced 4 records (User, Product, Transaction, Session) at 12:49:40
# Produced 4 records (User, Product, Transaction, Session) at 12:49:42
# Produced 4 records (User, Product, Transaction, Session) at 12:49:43
# Produced 4 records (User, Product, Transaction, Session) at 12:49:46
# Produced 4 records (User, Product, Transaction, Session) at 12:49:47
# Produced 4 records (User, Product, Transaction, Session) at 12:49:49
# Produced 4 records (User, Product, Transaction, Session) at 12:49:51
# Produced 4 records (User, Product, Transaction, Session) at 12:49:54
# Produced 4 records (User, Product, Transaction, Session) at 12:49:56
# Produced 4 records (User, Product, Transaction, Session) at 12:49:58
# Produced 4 records (User, Product, Transaction, Session) at 12:50:00
# Produced 4 records (User, Product, Transaction, Session) at 12:50:03
# Produced 4 records (User, Product, Transaction, Session) at 12:50:06
# Produced 4 records (User, Product, Transaction, Session) at 12:50:07
# Produced 4 records (User, Product, Transaction, Session) at 12:50:09
# Produced 4 records (User, Product, Transaction, Session) at 12:50:11
# Produced 4 records (User, Product, Transaction, Session) at 12:50:14
# Produced 4 records (User, Product, Transaction, Session) at 12:50:15
# Produced 4 records (User, Product, Transaction, Session) at 12:50:17
# Produced 4 records (User, Product, Transaction, Session) at 12:50:18
# Produced 4 records (User, Product, Transaction, Session) at 12:50:19
# Produced 4 records (User, Product, Transaction, Session) at 12:50:21
# Produced 4 records (User, Product, Transaction, Session) at 12:50:23
# Produced 4 records (User, Product, Transaction, Session) at 12:50:25
# Produced 4 records (User, Product, Transaction, Session) at 12:50:28
# Produced 4 records (User, Product, Transaction, Session) at 12:50:30
# Produced 4 records (User, Product, Transaction, Session) at 12:50:32
# Produced 4 records (User, Product, Transaction, Session) at 12:50:34
# Produced 4 records (User, Product, Transaction, Session) at 12:50:36
# Produced 4 records (User, Product, Transaction, Session) at 12:50:37
# Produced 4 records (User, Product, Transaction, Session) at 12:50:40
# Produced 4 records (User, Product, Transaction, Session) at 12:50:41
# Produced 4 records (User, Product, Transaction, Session) at 12:50:43
# Produced 4 records (User, Product, Transaction, Session) at 12:50:45
# Produced 4 records (User, Product, Transaction, Session) at 12:50:47
# Produced 4 records (User, Product, Transaction, Session) at 12:50:49
# Produced 4 records (User, Product, Transaction, Session) at 12:50:52
# Produced 4 records (User, Product, Transaction, Session) at 12:50:53
# Produced 4 records (User, Product, Transaction, Session) at 12:50:56
# Produced 4 records (User, Product, Transaction, Session) at 12:50:59
# Produced 4 records (User, Product, Transaction, Session) at 12:51:02
# Produced 4 records (User, Product, Transaction, Session) at 12:51:04
# Produced 4 records (User, Product, Transaction, Session) at 12:51:06
# Produced 4 records (User, Product, Transaction, Session) at 12:51:09
# Produced 4 records (User, Product, Transaction, Session) at 12:51:11
# Produced 4 records (User, Product, Transaction, Session) at 12:51:14
# Produced 4 records (User, Product, Transaction, Session) at 12:51:16
# Produced 4 records (User, Product, Transaction, Session) at 12:51:19
# Produced 4 records (User, Product, Transaction, Session) at 12:51:22
# Produced 4 records (User, Product, Transaction, Session) at 12:51:24
# Produced 4 records (User, Product, Transaction, Session) at 12:51:27
# Produced 4 records (User, Product, Transaction, Session) at 12:51:28
# Produced 4 records (User, Product, Transaction, Session) at 12:51:31
# Produced 4 records (User, Product, Transaction, Session) at 12:51:34
# Produced 4 records (User, Product, Transaction, Session) at 12:51:37
# Produced 4 records (User, Product, Transaction, Session) at 12:51:39
# Produced 4 records (User, Product, Transaction, Session) at 12:51:42
# Produced 4 records (User, Product, Transaction, Session) at 12:51:44
# Produced 4 records (User, Product, Transaction, Session) at 12:51:45
# Produced 4 records (User, Product, Transaction, Session) at 12:51:47
# Produced 4 records (User, Product, Transaction, Session) at 12:51:49
# Produced 4 records (User, Product, Transaction, Session) at 12:51:51
# Produced 4 records (User, Product, Transaction, Session) at 12:51:52
# Produced 4 records (User, Product, Transaction, Session) at 12:51:54
# Produced 4 records (User, Product, Transaction, Session) at 12:51:55
# Produced 4 records (User, Product, Transaction, Session) at 12:51:57
# Produced 4 records (User, Product, Transaction, Session) at 12:51:58
# Produced 4 records (User, Product, Transaction, Session) at 12:52:00
# Produced 4 records (User, Product, Transaction, Session) at 12:52:01
# Produced 4 records (User, Product, Transaction, Session) at 12:52:03
# Produced 4 records (User, Product, Transaction, Session) at 12:52:05
# Produced 4 records (User, Product, Transaction, Session) at 12:52:07
# Produced 4 records (User, Product, Transaction, Session) at 12:52:08
# Produced 4 records (User, Product, Transaction, Session) at 12:52:11
# Produced 4 records (User, Product, Transaction, Session) at 12:52:13
# Produced 4 records (User, Product, Transaction, Session) at 12:52:16
# Produced 4 records (User, Product, Transaction, Session) at 12:52:17
# Produced 4 records (User, Product, Transaction, Session) at 12:52:18
# Produced 4 records (User, Product, Transaction, Session) at 12:52:21
# Produced 4 records (User, Product, Transaction, Session) at 12:52:23
# Produced 4 records (User, Product, Transaction, Session) at 12:52:25
# Produced 4 records (User, Product, Transaction, Session) at 12:52:27
# Produced 4 records (User, Product, Transaction, Session) at 12:52:28
# Produced 4 records (User, Product, Transaction, Session) at 12:52:30
# Produced 4 records (User, Product, Transaction, Session) at 12:52:31
# Produced 4 records (User, Product, Transaction, Session) at 12:52:33
# Produced 4 records (User, Product, Transaction, Session) at 12:52:35
# Produced 4 records (User, Product, Transaction, Session) at 12:52:38
# Produced 4 records (User, Product, Transaction, Session) at 12:52:39
# Produced 4 records (User, Product, Transaction, Session) at 12:52:41
# Produced 4 records (User, Product, Transaction, Session) at 12:52:44
# Produced 4 records (User, Product, Transaction, Session) at 12:52:47
# Produced 4 records (User, Product, Transaction, Session) at 12:52:48
# Produced 4 records (User, Product, Transaction, Session) at 12:52:50
# Produced 4 records (User, Product, Transaction, Session) at 12:52:53
# Produced 4 records (User, Product, Transaction, Session) at 12:52:54
# Produced 4 records (User, Product, Transaction, Session) at 12:52:56
# Produced 4 records (User, Product, Transaction, Session) at 12:52:58
# Produced 4 records (User, Product, Transaction, Session) at 12:53:01
# Produced 4 records (User, Product, Transaction, Session) at 12:53:04
# Produced 4 records (User, Product, Transaction, Session) at 12:53:06
# Produced 4 records (User, Product, Transaction, Session) at 12:53:08
# Produced 4 records (User, Product, Transaction, Session) at 12:53:10
# Produced 4 records (User, Product, Transaction, Session) at 12:53:12
# Produced 4 records (User, Product, Transaction, Session) at 12:53:15
# Produced 4 records (User, Product, Transaction, Session) at 12:53:16
# Produced 4 records (User, Product, Transaction, Session) at 12:53:18
# Produced 4 records (User, Product, Transaction, Session) at 12:53:20
# Produced 4 records (User, Product, Transaction, Session) at 12:53:21
# Produced 4 records (User, Product, Transaction, Session) at 12:53:24
# Produced 4 records (User, Product, Transaction, Session) at 12:53:26
# Produced 4 records (User, Product, Transaction, Session) at 12:53:27
# Produced 4 records (User, Product, Transaction, Session) at 12:53:29
# Produced 4 records (User, Product, Transaction, Session) at 12:53:31
# Produced 4 records (User, Product, Transaction, Session) at 12:53:32
# Produced 4 records (User, Product, Transaction, Session) at 12:53:33
# Produced 4 records (User, Product, Transaction, Session) at 12:53:36
# Produced 4 records (User, Product, Transaction, Session) at 12:53:37
# Produced 4 records (User, Product, Transaction, Session) at 12:53:39
# Produced 4 records (User, Product, Transaction, Session) at 12:53:42
# Produced 4 records (User, Product, Transaction, Session) at 12:53:43
# Produced 4 records (User, Product, Transaction, Session) at 12:53:44
# Produced 4 records (User, Product, Transaction, Session) at 12:53:46
# Produced 4 records (User, Product, Transaction, Session) at 12:53:47
# Produced 4 records (User, Product, Transaction, Session) at 12:53:49
# Produced 4 records (User, Product, Transaction, Session) at 12:53:51
# Produced 4 records (User, Product, Transaction, Session) at 12:53:53
# Produced 4 records (User, Product, Transaction, Session) at 12:53:54
# Produced 4 records (User, Product, Transaction, Session) at 12:53:56
# Produced 4 records (User, Product, Transaction, Session) at 12:53:59
# Produced 4 records (User, Product, Transaction, Session) at 12:54:00
# Produced 4 records (User, Product, Transaction, Session) at 12:54:03
# Produced 4 records (User, Product, Transaction, Session) at 12:54:05
# Produced 4 records (User, Product, Transaction, Session) at 12:54:07
# Produced 4 records (User, Product, Transaction, Session) at 12:54:08
# Produced 4 records (User, Product, Transaction, Session) at 12:54:10
# Produced 4 records (User, Product, Transaction, Session) at 12:54:12
# Produced 4 records (User, Product, Transaction, Session) at 12:54:14
# Produced 4 records (User, Product, Transaction, Session) at 12:54:17
# Produced 4 records (User, Product, Transaction, Session) at 12:54:19
# Produced 4 records (User, Product, Transaction, Session) at 12:54:20
# Produced 4 records (User, Product, Transaction, Session) at 12:54:22
# Produced 4 records (User, Product, Transaction, Session) at 12:54:23
# Produced 4 records (User, Product, Transaction, Session) at 12:54:24
# Produced 4 records (User, Product, Transaction, Session) at 12:54:27
# Produced 4 records (User, Product, Transaction, Session) at 12:54:29
# Produced 4 records (User, Product, Transaction, Session) at 12:54:32
# Produced 4 records (User, Product, Transaction, Session) at 12:54:35
# Produced 4 records (User, Product, Transaction, Session) at 12:54:36
# Produced 4 records (User, Product, Transaction, Session) at 12:54:38
# Produced 4 records (User, Product, Transaction, Session) at 12:54:40
# Produced 4 records (User, Product, Transaction, Session) at 12:54:41
# Produced 4 records (User, Product, Transaction, Session) at 12:54:43
# Produced 4 records (User, Product, Transaction, Session) at 12:54:46
# Produced 4 records (User, Product, Transaction, Session) at 12:54:47
# Produced 4 records (User, Product, Transaction, Session) at 12:54:50
# Produced 4 records (User, Product, Transaction, Session) at 12:54:53
# Produced 4 records (User, Product, Transaction, Session) at 12:54:54
# Produced 4 records (User, Product, Transaction, Session) at 12:54:56
# Produced 4 records (User, Product, Transaction, Session) at 12:54:58
# Produced 4 records (User, Product, Transaction, Session) at 12:55:00
# Produced 4 records (User, Product, Transaction, Session) at 12:55:02
# Produced 4 records (User, Product, Transaction, Session) at 12:55:05
# Produced 4 records (User, Product, Transaction, Session) at 12:55:08
# Produced 4 records (User, Product, Transaction, Session) at 12:55:10
# Produced 4 records (User, Product, Transaction, Session) at 12:55:11
# Produced 4 records (User, Product, Transaction, Session) at 12:55:13
# Produced 4 records (User, Product, Transaction, Session) at 12:55:15
# Produced 4 records (User, Product, Transaction, Session) at 12:55:18
# Produced 4 records (User, Product, Transaction, Session) at 12:55:19
# Produced 4 records (User, Product, Transaction, Session) at 12:55:22
# Produced 4 records (User, Product, Transaction, Session) at 12:55:24
# Produced 4 records (User, Product, Transaction, Session) at 12:55:27
# Produced 4 records (User, Product, Transaction, Session) at 12:55:29
# Produced 4 records (User, Product, Transaction, Session) at 12:55:30
# Produced 4 records (User, Product, Transaction, Session) at 12:55:32
# Produced 4 records (User, Product, Transaction, Session) at 12:55:33
# Produced 4 records (User, Product, Transaction, Session) at 12:55:35
# Produced 4 records (User, Product, Transaction, Session) at 12:55:36
# Produced 4 records (User, Product, Transaction, Session) at 12:55:37
# Produced 4 records (User, Product, Transaction, Session) at 12:55:40
# Produced 4 records (User, Product, Transaction, Session) at 12:55:41
# Produced 4 records (User, Product, Transaction, Session) at 12:55:43
# Produced 4 records (User, Product, Transaction, Session) at 12:55:44
# Produced 4 records (User, Product, Transaction, Session) at 12:55:46
# Produced 4 records (User, Product, Transaction, Session) at 12:55:48
# Produced 4 records (User, Product, Transaction, Session) at 12:55:50
# Produced 4 records (User, Product, Transaction, Session) at 12:55:51
# Produced 4 records (User, Product, Transaction, Session) at 12:55:53
# Produced 4 records (User, Product, Transaction, Session) at 12:55:54
# Produced 4 records (User, Product, Transaction, Session) at 12:55:56
# Produced 4 records (User, Product, Transaction, Session) at 12:55:57
# Produced 4 records (User, Product, Transaction, Session) at 12:55:59
# Produced 4 records (User, Product, Transaction, Session) at 12:56:00
# Produced 4 records (User, Product, Transaction, Session) at 12:56:02
# Produced 4 records (User, Product, Transaction, Session) at 12:56:04
# Produced 4 records (User, Product, Transaction, Session) at 12:56:07
# Produced 4 records (User, Product, Transaction, Session) at 12:56:08
# Produced 4 records (User, Product, Transaction, Session) at 12:56:10
# Produced 4 records (User, Product, Transaction, Session) at 12:56:12
# Produced 4 records (User, Product, Transaction, Session) at 12:56:13
# Produced 4 records (User, Product, Transaction, Session) at 12:56:16
# Produced 4 records (User, Product, Transaction, Session) at 12:56:17
# Produced 4 records (User, Product, Transaction, Session) at 12:56:19
# Produced 4 records (User, Product, Transaction, Session) at 12:56:21
# Produced 4 records (User, Product, Transaction, Session) at 12:56:22
# Produced 4 records (User, Product, Transaction, Session) at 12:56:25
# Produced 4 records (User, Product, Transaction, Session) at 12:56:28
# Produced 4 records (User, Product, Transaction, Session) at 12:56:30
# Produced 4 records (User, Product, Transaction, Session) at 12:56:32
# Produced 4 records (User, Product, Transaction, Session) at 12:56:34
# Produced 4 records (User, Product, Transaction, Session) at 12:56:37
# Produced 4 records (User, Product, Transaction, Session) at 12:56:39
# Produced 4 records (User, Product, Transaction, Session) at 12:56:40
# Produced 4 records (User, Product, Transaction, Session) at 12:56:42
# Produced 4 records (User, Product, Transaction, Session) at 12:56:43
# Produced 4 records (User, Product, Transaction, Session) at 12:56:45
# Produced 4 records (User, Product, Transaction, Session) at 12:56:48
# Produced 4 records (User, Product, Transaction, Session) at 12:56:50
# Produced 4 records (User, Product, Transaction, Session) at 12:56:52
# Produced 4 records (User, Product, Transaction, Session) at 12:56:54
# Produced 4 records (User, Product, Transaction, Session) at 12:56:56
# Produced 4 records (User, Product, Transaction, Session) at 12:56:57
# Produced 4 records (User, Product, Transaction, Session) at 12:56:59
# Produced 4 records (User, Product, Transaction, Session) at 12:57:01
# Produced 4 records (User, Product, Transaction, Session) at 12:57:03
# Produced 4 records (User, Product, Transaction, Session) at 12:57:05
# Produced 4 records (User, Product, Transaction, Session) at 12:57:08
# Produced 4 records (User, Product, Transaction, Session) at 12:57:10
# Produced 4 records (User, Product, Transaction, Session) at 12:57:12
# Produced 4 records (User, Product, Transaction, Session) at 12:57:14
# Produced 4 records (User, Product, Transaction, Session) at 12:57:16
# Produced 4 records (User, Product, Transaction, Session) at 12:57:19
# Produced 4 records (User, Product, Transaction, Session) at 12:57:21
# Produced 4 records (User, Product, Transaction, Session) at 12:57:22
# Produced 4 records (User, Product, Transaction, Session) at 12:57:24
# Produced 4 records (User, Product, Transaction, Session) at 12:57:26
# Produced 4 records (User, Product, Transaction, Session) at 12:57:28
# Produced 4 records (User, Product, Transaction, Session) at 12:57:30
# Produced 4 records (User, Product, Transaction, Session) at 12:57:32
# Produced 4 records (User, Product, Transaction, Session) at 12:57:34
# Produced 4 records (User, Product, Transaction, Session) at 12:57:35
# Produced 4 records (User, Product, Transaction, Session) at 12:57:38
# Produced 4 records (User, Product, Transaction, Session) at 12:57:40
# Produced 4 records (User, Product, Transaction, Session) at 12:57:42
# Produced 4 records (User, Product, Transaction, Session) at 12:57:43
# Produced 4 records (User, Product, Transaction, Session) at 12:57:46
# Produced 4 records (User, Product, Transaction, Session) at 12:57:49
# Produced 4 records (User, Product, Transaction, Session) at 12:57:52
# Produced 4 records (User, Product, Transaction, Session) at 12:57:53
# Produced 4 records (User, Product, Transaction, Session) at 12:57:56
# Produced 4 records (User, Product, Transaction, Session) at 12:57:57
# Produced 4 records (User, Product, Transaction, Session) at 12:57:59
# Produced 4 records (User, Product, Transaction, Session) at 12:58:01
# Produced 4 records (User, Product, Transaction, Session) at 12:58:02
# Produced 4 records (User, Product, Transaction, Session) at 12:58:04
# Produced 4 records (User, Product, Transaction, Session) at 12:58:06
# Produced 4 records (User, Product, Transaction, Session) at 12:58:08
# Produced 4 records (User, Product, Transaction, Session) at 12:58:11
# Produced 4 records (User, Product, Transaction, Session) at 12:58:12
# Produced 4 records (User, Product, Transaction, Session) at 12:58:14
# Produced 4 records (User, Product, Transaction, Session) at 12:58:16
# Produced 4 records (User, Product, Transaction, Session) at 12:58:19
# Produced 4 records (User, Product, Transaction, Session) at 12:58:22
# Produced 4 records (User, Product, Transaction, Session) at 12:58:24
# Produced 4 records (User, Product, Transaction, Session) at 12:58:26
# Produced 4 records (User, Product, Transaction, Session) at 12:58:27
# Produced 4 records (User, Product, Transaction, Session) at 12:58:29
# Produced 4 records (User, Product, Transaction, Session) at 12:58:30
# Produced 4 records (User, Product, Transaction, Session) at 12:58:33
# Produced 4 records (User, Product, Transaction, Session) at 12:58:35
# Produced 4 records (User, Product, Transaction, Session) at 12:58:36
# Produced 4 records (User, Product, Transaction, Session) at 12:58:37
# Produced 4 records (User, Product, Transaction, Session) at 12:58:39
# Produced 4 records (User, Product, Transaction, Session) at 12:58:42
# Produced 4 records (User, Product, Transaction, Session) at 12:58:45
# Produced 4 records (User, Product, Transaction, Session) at 12:58:47
# Produced 4 records (User, Product, Transaction, Session) at 12:58:50
# Produced 4 records (User, Product, Transaction, Session) at 12:58:51
# Produced 4 records (User, Product, Transaction, Session) at 12:58:52
# Produced 4 records (User, Product, Transaction, Session) at 12:58:54
# Produced 4 records (User, Product, Transaction, Session) at 12:58:57
# Produced 4 records (User, Product, Transaction, Session) at 12:58:58
# Produced 4 records (User, Product, Transaction, Session) at 12:59:00
# Produced 4 records (User, Product, Transaction, Session) at 12:59:02
# Produced 4 records (User, Product, Transaction, Session) at 12:59:05
# Produced 4 records (User, Product, Transaction, Session) at 12:59:08
# Produced 4 records (User, Product, Transaction, Session) at 12:59:10
# Produced 4 records (User, Product, Transaction, Session) at 12:59:11
# Produced 4 records (User, Product, Transaction, Session) at 12:59:12
# Produced 4 records (User, Product, Transaction, Session) at 12:59:14
# Produced 4 records (User, Product, Transaction, Session) at 12:59:16
# Produced 4 records (User, Product, Transaction, Session) at 12:59:18
# Produced 4 records (User, Product, Transaction, Session) at 12:59:20
# Produced 4 records (User, Product, Transaction, Session) at 12:59:22
# Produced 4 records (User, Product, Transaction, Session) at 12:59:24
# Produced 4 records (User, Product, Transaction, Session) at 12:59:26
# Produced 4 records (User, Product, Transaction, Session) at 12:59:28
# Produced 4 records (User, Product, Transaction, Session) at 12:59:30
# Produced 4 records (User, Product, Transaction, Session) at 12:59:32
# Produced 4 records (User, Product, Transaction, Session) at 12:59:34
# Produced 4 records (User, Product, Transaction, Session) at 12:59:36
# Produced 4 records (User, Product, Transaction, Session) at 12:59:38
# Produced 4 records (User, Product, Transaction, Session) at 12:59:39
# Produced 4 records (User, Product, Transaction, Session) at 12:59:41
# Produced 4 records (User, Product, Transaction, Session) at 12:59:43
# Produced 4 records (User, Product, Transaction, Session) at 12:59:45
# Produced 4 records (User, Product, Transaction, Session) at 12:59:48
# Produced 4 records (User, Product, Transaction, Session) at 12:59:49
# Produced 4 records (User, Product, Transaction, Session) at 12:59:52
# Produced 4 records (User, Product, Transaction, Session) at 12:59:55
# Produced 4 records (User, Product, Transaction, Session) at 12:59:57
# Produced 4 records (User, Product, Transaction, Session) at 12:59:58
# Produced 4 records (User, Product, Transaction, Session) at 12:59:59
# Produced 4 records (User, Product, Transaction, Session) at 13:00:01
# Produced 4 records (User, Product, Transaction, Session) at 13:00:03
# Produced 4 records (User, Product, Transaction, Session) at 13:00:04
# Produced 4 records (User, Product, Transaction, Session) at 13:00:06
# Produced 4 records (User, Product, Transaction, Session) at 13:00:07
# Produced 4 records (User, Product, Transaction, Session) at 13:00:10
# Produced 4 records (User, Product, Transaction, Session) at 13:00:11
# Produced 4 records (User, Product, Transaction, Session) at 13:00:12
# Produced 4 records (User, Product, Transaction, Session) at 13:00:15
# Produced 4 records (User, Product, Transaction, Session) at 13:00:16
# Produced 4 records (User, Product, Transaction, Session) at 13:00:18
# Produced 4 records (User, Product, Transaction, Session) at 13:00:20
# Produced 4 records (User, Product, Transaction, Session) at 13:00:22
# Produced 4 records (User, Product, Transaction, Session) at 13:00:23
# Produced 4 records (User, Product, Transaction, Session) at 13:00:25
# Produced 4 records (User, Product, Transaction, Session) at 13:00:28
# Produced 4 records (User, Product, Transaction, Session) at 13:00:30
# Produced 4 records (User, Product, Transaction, Session) at 13:00:33
# Produced 4 records (User, Product, Transaction, Session) at 13:00:34
# Produced 4 records (User, Product, Transaction, Session) at 13:00:37
# Produced 4 records (User, Product, Transaction, Session) at 13:00:38
# Produced 4 records (User, Product, Transaction, Session) at 13:00:41
# Produced 4 records (User, Product, Transaction, Session) at 13:00:42
# Produced 4 records (User, Product, Transaction, Session) at 13:00:44
# Produced 4 records (User, Product, Transaction, Session) at 13:00:46
# Produced 4 records (User, Product, Transaction, Session) at 13:00:47
# Produced 4 records (User, Product, Transaction, Session) at 13:00:49
# Produced 4 records (User, Product, Transaction, Session) at 13:00:51
# Produced 4 records (User, Product, Transaction, Session) at 13:00:54
# Produced 4 records (User, Product, Transaction, Session) at 13:00:55
# Produced 4 records (User, Product, Transaction, Session) at 13:00:57
# Produced 4 records (User, Product, Transaction, Session) at 13:00:59
# Produced 4 records (User, Product, Transaction, Session) at 13:01:01
# Produced 4 records (User, Product, Transaction, Session) at 13:01:02
# Produced 4 records (User, Product, Transaction, Session) at 13:01:04
# Produced 4 records (User, Product, Transaction, Session) at 13:01:07
# Produced 4 records (User, Product, Transaction, Session) at 13:01:08
# Produced 4 records (User, Product, Transaction, Session) at 13:01:11
# Produced 4 records (User, Product, Transaction, Session) at 13:01:13
# Produced 4 records (User, Product, Transaction, Session) at 13:01:14
# Produced 4 records (User, Product, Transaction, Session) at 13:01:16
# Produced 4 records (User, Product, Transaction, Session) at 13:01:18
# Produced 4 records (User, Product, Transaction, Session) at 13:01:21
# Produced 4 records (User, Product, Transaction, Session) at 13:01:24
# Produced 4 records (User, Product, Transaction, Session) at 13:01:25
# Produced 4 records (User, Product, Transaction, Session) at 13:01:27
# Produced 4 records (User, Product, Transaction, Session) at 13:01:30
# Produced 4 records (User, Product, Transaction, Session) at 13:01:32
# Produced 4 records (User, Product, Transaction, Session) at 13:01:34
# Produced 4 records (User, Product, Transaction, Session) at 13:01:36
# Produced 4 records (User, Product, Transaction, Session) at 13:01:37
# Produced 4 records (User, Product, Transaction, Session) at 13:01:39
# Produced 4 records (User, Product, Transaction, Session) at 13:01:42
# Produced 4 records (User, Product, Transaction, Session) at 13:01:44
# Produced 4 records (User, Product, Transaction, Session) at 13:01:46
# Produced 4 records (User, Product, Transaction, Session) at 13:01:48
# Produced 4 records (User, Product, Transaction, Session) at 13:01:50
# Produced 4 records (User, Product, Transaction, Session) at 13:01:52
# Produced 4 records (User, Product, Transaction, Session) at 13:01:54
# Produced 4 records (User, Product, Transaction, Session) at 13:01:56
# Produced 4 records (User, Product, Transaction, Session) at 13:01:58
# Produced 4 records (User, Product, Transaction, Session) at 13:02:01
# Produced 4 records (User, Product, Transaction, Session) at 13:02:03
# Produced 4 records (User, Product, Transaction, Session) at 13:02:05
# Produced 4 records (User, Product, Transaction, Session) at 13:02:07
# Produced 4 records (User, Product, Transaction, Session) at 13:02:10
# Produced 4 records (User, Product, Transaction, Session) at 13:02:11
# Produced 4 records (User, Product, Transaction, Session) at 13:02:13
# Produced 4 records (User, Product, Transaction, Session) at 13:02:16
# Produced 4 records (User, Product, Transaction, Session) at 13:02:18
# Produced 4 records (User, Product, Transaction, Session) at 13:02:19
# Produced 4 records (User, Product, Transaction, Session) at 13:02:21
# Produced 4 records (User, Product, Transaction, Session) at 13:02:22
# Produced 4 records (User, Product, Transaction, Session) at 13:02:24
# Produced 4 records (User, Product, Transaction, Session) at 13:02:26
#
# Stopping stream...
# Producer closed.
