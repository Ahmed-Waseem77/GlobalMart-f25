# %% [markdown]
# # Validating the Kafka Data Stream

# %%
# !pip install kafka-python

# %%
from kafka import KafkaConsumer
from IPython.display import clear_output
import json
import pprint

# connect to kafka and print the data
KAFKA_BROKERS = ['kafka1:9092', 'kafka2:9092']
TOPICS = {
    'users': 'new_users',
    'transactions': 'new_transactions',
    'products': 'new_products',
    'sessions': 'new_sessions'
}

consumer = KafkaConsumer(
    *TOPICS.values(),
    bootstrap_servers=KAFKA_BROKERS,
    auto_offset_reset='earliest',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

pp = pprint.PrettyPrinter(indent=4)

for i, message in enumerate(consumer):
    if i % 20 == 0:
        clear_output(wait=True)
    
    print(f"Topic: {message.topic}, Partition: {message.partition}, Offset: {message.offset}")
    print(f"Key: {message.key}")
    print("Value:")
    pp.pprint(message.value)
    print("-" * 50)
# Out:
# Topic: new_transactions, Partition: 0, Offset: 4856
# Key: None
# Value:
# {   'payment_method': 'Debit Card',
#     'products': [   {   'price': 1226.74,
#                         'product_id': '25d5d08b-6d39-44f5-af55-2973c16649eb',
#                         'quantity': 3},
#                     {   'price': 119.56,
#                         'product_id': '2d052f15-9bb1-423a-996a-7b62ca51c839',
#                         'quantity': 1},
#                     {   'price': 83.23,
#                         'product_id': 'f7485d8b-e92d-4279-8674-2d9975d843da',
#                         'quantity': 3},
#                     {   'price': 119.56,
#                         'product_id': '2d052f15-9bb1-423a-996a-7b62ca51c839',
#                         'quantity': 1}],
#     'timestamp': '2025-11-25T14:15:24.110686',
#     'transaction_id': 'ee192e8c-62f5-406f-9720-75b701c1b89d',
#     'user_id': '4aa59281-7df4-4834-a8a7-754cd36537e7'}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 4857
# Key: None
# Value:
# {   'payment_method': 'Credit Card',
#     'products': [   {   'price': 197.99,
#                         'product_id': '1d992338-300e-41d5-9305-33e41295784f',
#                         'quantity': 3},
#                     {   'price': 150.08,
#                         'product_id': 'cf7c3727-0c98-4618-af28-24f3b7e92db5',
#                         'quantity': 1},
#                     {   'price': 366.77,
#                         'product_id': '97fafa92-52d9-4e4f-a9d8-b22c522d14e8',
#                         'quantity': 1},
#                     {   'price': 2645.61,
#                         'product_id': 'b8ded049-8480-454e-a477-4e2707360aa4',
#                         'quantity': 1}],
#     'timestamp': '2025-11-25T14:15:24.111478',
#     'transaction_id': '1c5e99ba-6928-4bff-862d-960577608423',
#     'user_id': 'df0eeca2-2123-4866-a271-a979e5348a11'}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 4858
# Key: None
# Value:
# {   'payment_method': 'Apple Pay',
#     'products': [   {   'price': 87.72,
#                         'product_id': 'aa88e2c7-6963-4b46-93aa-136d4c6c68c2',
#                         'quantity': 1},
#                     {   'price': 126.16,
#                         'product_id': 'f45e0bac-367e-4a4d-b15e-1707753b7305',
#                         'quantity': 2}],
#     'timestamp': '2025-11-25T14:15:24.112166',
#     'transaction_id': '6a3ae1ad-93fc-4f4f-bc19-f4042d6d9207',
#     'user_id': '7830b511-bc44-4eb9-9b09-f1a12c7c0cef'}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 4859
# Key: None
# Value:
# {   'payment_method': 'Apple Pay',
#     'products': [   {   'price': 1066.72,
#                         'product_id': '08b47c68-ead1-437b-94a4-3507211095d8',
#                         'quantity': 3},
#                     {   'price': 83.23,
#                         'product_id': 'f7485d8b-e92d-4279-8674-2d9975d843da',
#                         'quantity': 3},
#                     {   'price': 495.85,
#                         'product_id': '94abc64c-a035-4e16-9da4-aee9d6931044',
#                         'quantity': 2}],
#     'timestamp': '2025-11-25T14:15:24.112772',
#     'transaction_id': 'c87e3957-acf7-4e21-859f-55796a613b6a',
#     'user_id': '6abeb32d-8f02-4faa-a3cb-561965a25fd4'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4852
# Key: None
# Value:
# {   'events': [   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.103571'},
#                   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.103571'}],
#     'session_id': 'e55e5a58-1be7-4c34-9918-c739a794799b',
#     'timestamp': '2025-11-25T14:15:24.107343',
#     'user_id': '6abeb32d-8f02-4faa-a3cb-561965a25fd4'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4853
# Key: None
# Value:
# {   'events': [   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.108496'},
#                   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.108496'},
#                   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.108496'}],
#     'session_id': '418aaf1a-8ad7-44e3-b3de-b05452ec77d3',
#     'timestamp': '2025-11-25T14:15:24.108592',
#     'user_id': '62a324a3-92de-4919-ae26-9d724ea89c40'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4854
# Key: None
# Value:
# {   'events': [   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.109299'}],
#     'session_id': 'e9d444dc-465c-4a7a-a0b1-6d59bfed3589',
#     'timestamp': '2025-11-25T14:15:24.109368',
#     'user_id': 'b5831b7e-3fd8-45e4-afc0-f1287d6c5a34'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4855
# Key: None
# Value:
# {   'events': [   {   'eventType': None,
#                       'timestamp': '2025-11-25T14:15:24.110200'},
#                   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.110200'},
#                   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.110200'},
#                   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.110200'},
#                   {   'eventType': 'CLEAR_CART',
#                       'timestamp': '2025-11-25T14:15:24.110200'},
#                   {   'eventType': 'CLEAR_CART',
#                       'timestamp': '2025-11-25T14:15:24.110200'},
#                   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.110200'},
#                   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.110200'}],
#     'session_id': 'b41e118c-3da6-489b-abdd-569c235bda58',
#     'timestamp': '2025-11-25T14:15:24.110311',
#     'user_id': '4aa59281-7df4-4834-a8a7-754cd36537e7'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4856
# Key: None
# Value:
# {   'events': [   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.110952'},
#                   {   'eventType': 'CLEAR_CART',
#                       'timestamp': '2025-11-25T14:15:24.110952'},
#                   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.110952'},
#                   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.110952'}],
#     'session_id': '1f34e1f8-09f0-446f-b2ee-4b44b1d1f53c',
#     'timestamp': '2025-11-25T14:15:24.111050',
#     'user_id': 'da6b19cd-ead1-4363-9619-2cdad5a7f979'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4857
# Key: None
# Value:
# {   'events': [   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.111767'},
#                   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.111767'},
#                   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.111767'},
#                   {   'eventType': 'CLEAR_CART',
#                       'timestamp': '2025-11-25T14:15:24.111767'},
#                   {   'eventType': 'REMOVE_FROM_CART',
#                       'timestamp': '2025-11-25T14:15:24.111767'}],
#     'session_id': '0acc2e90-bbf5-47fa-a7f6-1d04b7c0fc84',
#     'timestamp': '2025-11-25T14:15:24.111854',
#     'user_id': '4aa59281-7df4-4834-a8a7-754cd36537e7'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4858
# Key: None
# Value:
# {   'events': [   {   'eventType': 'CLEAR_CART',
#                       'timestamp': '2025-11-25T14:15:24.112388'},
#                   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.112388'}],
#     'session_id': '71bcea3b-0af0-4fc3-b4aa-94e090e99f87',
#     'timestamp': '2025-11-25T14:15:24.112458',
#     'user_id': 'df0eeca2-2123-4866-a271-a979e5348a11'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 4859
# Key: None
# Value:
# {   'events': [   {   'eventType': 'ADD_TO_CART',
#                       'timestamp': '2025-11-25T14:15:24.113005'}],
#     'session_id': '723157ff-8aba-4c80-9286-8acb37602cd8',
#     'timestamp': '2025-11-25T14:15:24.113067',
#     'user_id': '6abeb32d-8f02-4faa-a3cb-561965a25fd4'}
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 24
#      15 consumer = KafkaConsumer(
#      16     *TOPICS.values(),
#      17     bootstrap_servers=KAFKA_BROKERS,
#      18     auto_offset_reset='earliest',
#      19     value_deserializer=lambda x: json.loads(x.decode('utf-8'))
#      20 )
#      22 pp = pprint.PrettyPrinter(indent=4)
# ---> 24 for i, message in enumerate(consumer):
#      25     if i % 20 == 0:
#      26         clear_output(wait=True)
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /opt/conda/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:
