# %% [markdown]
# # Validating the Kafka Data Stream

# %%
# !pip install kafka-python

# %%
# connect to kafka and print the data
KAFKA_BROKERS = ['kafka1:9092', 'kafka2:9092']
TOPICS = {
    'users': 'new_users',
    'transactions': 'new_transactions',
    'products': 'new_products',
    'sessions': 'new_sessions'
}
    

from kafka import KafkaConsumer
from IPython.display import clear_output
import json

consumer = KafkaConsumer(
    *TOPICS.values(),
    bootstrap_servers=KAFKA_BROKERS,
    auto_offset_reset='earliest',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

for i, message in enumerate(consumer):
    if i % 20 == 0:
        clear_output(wait=True)
    
    print(f"Topic: {message.topic}, Partition: {message.partition}, Offset: {message.offset}")
    print(f"Key: {message.key}, Value: {message.value}")
    print("-" * 50)
# Out:
# Topic: new_users, Partition: 0, Offset: 350
# Key: None, Value: {'user_id': 'bfa4dd30-d977-4b38-b6e7-b9151a413ddf', 'email': 'user_779924@example.com', 'age': 77, 'country': 'Japan', 'registeration_date': '2025-11-24T10:33:18.180350'}
# --------------------------------------------------
# Topic: new_products, Partition: 0, Offset: 350
# Key: None, Value: {'product_id': '100ed697-8deb-4d6a-80dc-3f7c5d464481', 'name': 'Product_9021', 'category': 'Clothing', 'price': 1604.39, 'inventory': 275, 'ratings': 2.2}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 350
# Key: None, Value: {'transaction_id': 'b98e4659-8f94-46be-93ba-f6d605a564b3', 'user_id': '06e7d816-9b03-4a93-b8c9-c39e3822938c', 'timestamp': '2025-11-24T10:33:18.180776', 'products': [{'product_id': '5c1e4fba-aca7-499f-8c0b-2bcb97c71de8', 'quantity': 3, 'price': 782.59}, {'product_id': '6e9a46c8-0a14-4276-9ceb-1155d0772920', 'quantity': 3, 'price': 306.88}, {'product_id': '27b5c2dc-4b22-4ae5-9e8c-763beb954411', 'quantity': 1, 'price': 933.45}, {'product_id': 'c4e93d76-b2b1-4690-be33-cbab7bc06465', 'quantity': 2, 'price': 43.09}], 'total_amount': 4288.04, 'payment_method': 'Google Pay'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 350
# Key: None, Value: {'user_id': '1963808f-187c-45da-abee-f355d204a958', 'session_id': '6af9a979-c72a-453d-a95b-b7edf8b0677d', 'timestamp': '2025-11-24T10:33:18.180903', 'events': [{'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-24T10:33:18.180870'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-24T10:33:18.180870'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-24T10:33:18.180870'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-24T10:33:18.180870'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-24T10:33:18.180870'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-24T10:33:18.180870'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-24T10:33:18.180870'}]}
# --------------------------------------------------
# Topic: new_users, Partition: 0, Offset: 351
# Key: None, Value: {'user_id': 'fe6d8f93-59da-4184-abf8-40071fee9344', 'email': 'user_606248@example.com', 'age': 75, 'country': 'USA', 'registeration_date': '2025-11-24T10:33:19.535585'}
# --------------------------------------------------
# Topic: new_products, Partition: 0, Offset: 351
# Key: None, Value: {'product_id': 'fb7d376f-5843-4d13-8be8-9421a8499130', 'name': 'Product_6104', 'category': 'Books', 'price': 1557.28, 'inventory': 283, 'ratings': 1.5}
# --------------------------------------------------
# Topic: new_transactions, Partition: 0, Offset: 351
# Key: None, Value: {'transaction_id': 'be6193c1-918f-4d33-82e6-597421463d36', 'user_id': 'eb49cfcf-dcf8-415c-b989-489eb848962f', 'timestamp': '2025-11-24T10:33:19.536670', 'products': [{'product_id': '4f7ed9a0-dc09-4897-879f-145ceb82773c', 'quantity': 2, 'price': 492.44}, {'product_id': '382b1a00-5aff-4c07-8181-18a1128d4c16', 'quantity': 3, 'price': 839.47}, {'product_id': '24f35601-964e-45d6-b97d-649ea5789123', 'quantity': 1, 'price': 713.22}, {'product_id': '2cd5d096-38a9-48fd-bef3-a53bbce7b6f5', 'quantity': 3, 'price': 651.38}, {'product_id': '9dfbdfa8-402f-4cba-859e-34ac7463e4fb', 'quantity': 2, 'price': 551.46}], 'total_amount': 7273.57, 'payment_method': 'PayPal'}
# --------------------------------------------------
# Topic: new_sessions, Partition: 0, Offset: 351
# Key: None, Value: {'user_id': '0178208d-7eb6-4cf9-9cbf-f82b2590c773', 'session_id': 'a92784ee-1cfa-4fbf-849f-d827c46252a4', 'timestamp': '2025-11-24T10:33:19.536902', 'events': [{'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-24T10:33:19.536827'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-24T10:33:19.536827'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-24T10:33:19.536827'}, {'eventType': 'CLEAR_CART', 'timestamp': '2025-11-24T10:33:19.536827'}, {'eventType': 'REMOVE_FROM_CART', 'timestamp': '2025-11-24T10:33:19.536827'}, {'eventType': 'ADD_TO_CART', 'timestamp': '2025-11-24T10:33:19.536827'}]}
# --------------------------------------------------
