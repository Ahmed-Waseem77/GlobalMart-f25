# %% [markdown]
# # Validating the Kafka Data Stream

# %%
# !pip install kafka-python

# %%
from kafka import KafkaConsumer
from IPython.display import clear_output
import json
import pprint

# connect to kafka and print the data
KAFKA_BROKERS = ['kafka1:9092', 'kafka2:9092']
TOPICS = {
    'users': 'new_users',
    'transactions': 'new_transactions',
    'products': 'new_products',
    'sessions': 'new_sessions'
}

consumer = KafkaConsumer(
    *TOPICS.values(),
    bootstrap_servers=KAFKA_BROKERS,
    auto_offset_reset='earliest',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

pp = pprint.PrettyPrinter(indent=4)

for i, message in enumerate(consumer):
    if i % 20 == 0:
        clear_output(wait=True)
    
    print(f"Topic: {message.topic}, Partition: {message.partition}, Offset: {message.offset}")
    print(f"Key: {message.key}")
    print("Value:")
    pp.pprint(message.value)
    print("-" * 50)
# Out:
# Topic: new_products, Partition: 0, Offset: 1995
# Key: None
# Value:
# {   'category': 'Home',
#     'inventory': 338,
#     'name': 'Home_Product_874',
#     'price': 369.59,
#     'product_id': 'e7a4dccd-0631-4393-9e49-9c97028c4aa9',
#     'ratings': 3.7}
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 24
#      15 consumer = KafkaConsumer(
#      16     *TOPICS.values(),
#      17     bootstrap_servers=KAFKA_BROKERS,
#      18     auto_offset_reset='earliest',
#      19     value_deserializer=lambda x: json.loads(x.decode('utf-8'))
#      20 )
#      22 pp = pprint.PrettyPrinter(indent=4)
# ---> 24 for i, message in enumerate(consumer):
#      25     if i % 20 == 0:
#      26         clear_output(wait=True)
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:743, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     741     futures = self._fetcher.send_fetches()
#     742     if len(futures):
# --> 743         self._client.poll(timeout_ms=0)
#     745 if records:
#     746     return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:781, in KafkaClient._poll(self, timeout)
#     778         continue
#     780     self._idle_expiry_manager.update(conn.node_id)
# --> 781     self._pending_completion.extend(conn.recv())
#     783 # Check for additional pending SSL bytes
#     784 if self.config['security_protocol'] in ('SSL', 'SASL_SSL'):
#     785     # TODO: optimize
#
# File /opt/conda/lib/python3.11/site-packages/kafka/conn.py:1131, in BrokerConnection.recv(self)
#    1126 def recv(self):
#    1127     """Non-blocking network receive.
#    1128
#    1129     Return list of (response, future) tuples
#    1130     """
# -> 1131     responses = self._recv()
#    1132     if not responses and self.requests_timed_out():
#    1133         timed_out = self.timed_out_ifrs()
#
# File /opt/conda/lib/python3.11/site-packages/kafka/conn.py:1208, in BrokerConnection._recv(self)
#    1204 # We need to keep the lock through protocol receipt
#    1205 # so that we ensure that the processed byte order is the
#    1206 # same as the received byte order
#    1207 try:
# -> 1208     return self._protocol.receive_bytes(recvd_data)
#    1209 except Errors.KafkaProtocolError as e:
#    1210     err = e
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/parser.py:130, in KafkaProtocol.receive_bytes(self, data)
#     128 self._receiving = False
#     129 self._rbuffer.seek(0)
# --> 130 resp = self._process_response(self._rbuffer)
#     131 responses.append(resp)
#     132 self._reset_buffer()
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/parser.py:162, in KafkaProtocol._process_response(self, read_buffer)
#     160 log.debug('Processing response %s', response_type.__name__)
#     161 try:
# --> 162     response = response_type.decode(read_buffer)
#     163 except ValueError:
#     164     read_buffer.seek(0)
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/struct.py:49, in Struct.decode(cls, data)
#      47 if isinstance(data, bytes):
#      48     data = BytesIO(data)
# ---> 49 return cls(*[field.decode(data) for field in cls.SCHEMA.fields])
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/struct.py:49, in <listcomp>(.0)
#      47 if isinstance(data, bytes):
#      48     data = BytesIO(data)
# ---> 49 return cls(*[field.decode(data) for field in cls.SCHEMA.fields])
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:207, in Array.decode(self, data)
#     205 if length == -1:
#     206     return None
# --> 207 return [self.array_of.decode(data) for _ in range(length)]
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:207, in <listcomp>(.0)
#     205 if length == -1:
#     206     return None
# --> 207 return [self.array_of.decode(data) for _ in range(length)]
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:165, in Schema.decode(self, data)
#     164 def decode(self, data):
# --> 165     return tuple([field.decode(data) for field in self.fields])
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:165, in <listcomp>(.0)
#     164 def decode(self, data):
# --> 165     return tuple([field.decode(data) for field in self.fields])
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:207, in Array.decode(self, data)
#     205 if length == -1:
#     206     return None
# --> 207 return [self.array_of.decode(data) for _ in range(length)]
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:207, in <listcomp>(.0)
#     205 if length == -1:
#     206     return None
# --> 207 return [self.array_of.decode(data) for _ in range(length)]
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:165, in Schema.decode(self, data)
#     164 def decode(self, data):
# --> 165     return tuple([field.decode(data) for field in self.fields])
#
# File /opt/conda/lib/python3.11/site-packages/kafka/protocol/types.py:165, in <listcomp>(.0)
#     164 def decode(self, data):
# --> 165     return tuple([field.decode(data) for field in self.fields])
#
# KeyboardInterrupt:
